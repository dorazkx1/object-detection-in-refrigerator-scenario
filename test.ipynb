# %%
print("a")

# %%
from ultralytics import YOLO
model = YOLO("yolov8s.pt")
data_yaml = '/Users/a1/Downloads/HLCV project/project/data/testdata/testsample1/data.yaml'
metrics = model.val(data=data_yaml, split="test", conf=0.001, iou=0.4)

# %%
print(float(results.box.map))

# %%
import yaml
with open(data_yaml, 'r') as file:
    data = yaml.safe_load(file)
print(data)
print(data.get("val"))

# %%
import numpy as np
a= np.arange(10)
b = np.array(((0,1,1),(0,1,1),(0,0,0)))
c,d = np.where(b)
print(c,d)
width = np.max(c) - np.min(c)
print((np.min(c)+ np.floor(width/2)))
center = np.array([[1,2]])
print(center)
# Out:
# [0 0 1 1] [1 2 1 2]
# 0.0
# [[1 2]]

# %%
items = ["a","b","c"]
for index, value in enumerate(items):
    print(f"Index: {index}, Value: {value}")
# Out:
# Index: 0, Value: a
# Index: 1, Value: b
# Index: 2, Value: c
